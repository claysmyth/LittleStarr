# %%
# %load_ext autoreload
# %autoreload 2

# %%
import altair as alt
import polars as pl
import pandas as pd
import sys
sys.path.append('../visualization_functions')
import altair_utils as alt_utils
import numpy as np
import seaborn as sns

# %%
import plotly.io as pio
alt.data_transformers.disable_max_rows()
dataspell = False
use_data_server = True # Use data server if you want to use the Vega Editor window
use_browser_for_plotly=False
remote = True

# The below commands allow for Altair to plot large data sets.

if dataspell:
    if use_data_server:
        alt.data_transformers.enable('data_server') # <- Exports to temporary localHost URL
        print('Data Server Enabled')
    else:
        vf.enable()
        print('VegaFusion Enabled')
    if use_browser_for_plotly:
        pio.renderers.default = 'browser'
    print("DataSpell Setup")
else:
    if not remote:
        # DO NOT RUN BELOW IN REMOTE VSCODE.
        if use_data_server:
            alt.data_transformers.enable('data_server') # <- Exports to temporary localHost URL
            print('Data Server Enabled')
        else:
            vf.enable_widget(data_dir='/media/shortterm_ssd/Clay/altairdata/')
            print('VegaFusion Widget Enabled')

    if use_browser_for_plotly:
        pio.renderers.default = 'browser'
        print("Plotly Browser Enabled")

    from plotly_resampler import register_plotly_resampler, unregister_plotly_resampler
    register_plotly_resampler(mode='auto')
    print("Plotly Resampler Enabled")
    print("VS Code")
'''
Available templates:
        ['ggplot2', 'seaborn', 'simple_white', 'plotly',
         'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
         'ygridoff', 'gridon', 'none']
'''
pio.templates.default = "plotly_white"
# Out:
# Plotly Resampler Enabled
# VS Code

# %%
parts = {}
charts = {}
parts_2 = {}

# %%
parts['02L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02L/hyperparameter_search_results_only_cortical.parquet')
parts['02L_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02L/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['02R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02R/hyperparameter_search_results_only_cortical.parquet')
parts['02R_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02R/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['03L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03L/hyperparameter_search_results_only_cortical.parquet')
parts['03L_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03L/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['03R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03R/hyperparameter_search_results_only_cortical.parquet')
parts['03R_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03R/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['07L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07L/hyperparameter_search_results_only_cortical.parquet')
parts['07L_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07L/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['07R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07R/hyperparameter_search_results_only_cortical.parquet')
parts['07R_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07R/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['09L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09L/hyperparameter_search_results_only_cortical.parquet')
parts['09L_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09L/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['09R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09R/hyperparameter_search_results_only_cortical.parquet')
parts['09R_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09R/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['16L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16L/hyperparameter_search_results_only_cortical.parquet')
parts['16L_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16L/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

parts['16R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16R/hyperparameter_search_results_only_cortical.parquet')
parts['16R_2LDA'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16R/hyperparameter_search_results_TwoStepLDATree_only_cortical_scoring_AUC.parquet')

# %%
parts_2['02L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02L/hyperparameter_search_results_only_cortical.parquet')
parts_2['02R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02R/hyperparameter_search_results_only_cortical.parquet')
parts_2['03L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03L/hyperparameter_search_results_only_cortical.parquet')
parts_2['03R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03R/hyperparameter_search_results_only_cortical.parquet')
parts_2['07L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07L/hyperparameter_search_results_only_cortical.parquet')
parts_2['07R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07R/hyperparameter_search_results_only_cortical.parquet')
parts_2['09L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09L/hyperparameter_search_results_only_cortical.parquet')
parts_2['09R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09R/hyperparameter_search_results_only_cortical.parquet')
parts_2['16L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16L/hyperparameter_search_results_only_cortical.parquet')
parts_2['16R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16R/hyperparameter_search_results_only_cortical.parquet')

# %%
# graphs = ['Acc', 'AUC', 'BalAcc', 'TPR', 'precision', 'TNR']
graphs = ['AUC']
for key, part in parts.items():
    chart=alt.vconcat()
    for i, col in enumerate(graphs):
        df = part.sort(col, descending=True).with_row_count().head(200).to_pandas()
        chart_tmp, df = alt_utils.create_overlaid_line_plot(df, ['row_nr'], ['Acc', 'AUC', 'TPR', 'TNR'], width=500, height=300, color_scheme='category10', interactive=True)
        chart &= chart_tmp
    charts[key] = chart

# %%
for key, chart in charts.items():
    chart = chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    ).properties(
        title={
            "text": key,
            "fontSize": 25,
            "fontWeight": "bold",
            "anchor": "middle"
        }
    )
    display(chart)
# Out:
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %%
# graphs = ['Acc', 'AUC', 'BalAcc', 'TPR', 'precision', 'TNR']
graphs = ['AUC']
for key, part in parts_2.items():
    chart=alt.vconcat()
    for i, col in enumerate(graphs):
        df = part.sort(col, descending=True).with_row_count().head(200).to_pandas()
        chart_tmp, df = alt_utils.create_overlaid_line_plot(df, ['row_nr'], ['Acc', 'AUC', 'TPR', 'TNR'], width=500, height=300, color_scheme='category10', interactive=True)
        chart &= chart_tmp
    charts[key] = chart
for key, chart in charts.items():
    chart = chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    ).properties(
        title={
            "text": key,
            "fontSize": 25,
            "fontWeight": "bold",
            "anchor": "middle"
        }
    )
    display(chart)
# Out:
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %%
for key, chart in charts.items():
    chart = chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    ).properties(
        title={
            "text": key,
            "fontSize": 25,
            "fontWeight": "bold",
            "anchor": "middle"
        }
    )
    display(chart)
# Out:
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %%
sup_chart = alt.vconcat()

graphs = ['AUC']
for key, part in parts.items():
    for i, col in enumerate(graphs):
        df = part.sort(col, descending=True).with_row_count().head(200).to_pandas()
        chart_tmp, df = alt_utils.create_overlaid_line_plot(df, ['row_nr'], ['Acc', 'AUC', 'BalAcc', 'TPR', 'precision', 'TNR'], width=500, height=300, color_scheme='category10', interactive=True)
        chart_tmp.properties(title={'text': key, 'fontSize': 25, 'fontWeight': 'bold', 'anchor': 'middle'})
        sup_chart &= chart_tmp

sup_chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    )
# Out:
# alt.VConcatChart(...)

# %%
parts['02L'].select(pl.all().exclude(list(set([col for col in parts['02L'].columns if 'PB' in col]) - set(['PB1', 'PB2', 'PB4']))))
# Out:
# shape: (640, 16)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬──────────┬──────────┬────────────┬──────────┐
# │ PB1       ┆ PB2       ┆ PB4       ┆ UpdateRa ┆ ... ┆ BalAcc_s ┆ TPR_std  ┆ precision_ ┆ TNR_std  │
# │ ---       ┆ ---       ┆ ---       ┆ te       ┆     ┆ td       ┆ ---      ┆ std        ┆ ---      │
# │ list[i64] ┆ list[i64] ┆ list[i64] ┆ ---      ┆     ┆ ---      ┆ f64      ┆ ---        ┆ f64      │
# │           ┆           ┆           ┆ i64      ┆     ┆ f64      ┆          ┆ f64        ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪══════════╪══════════╪════════════╪══════════╡
# │ [515,     ┆ [1146,    ┆ [null,    ┆ 2        ┆ ... ┆ 0.003494 ┆ 0.006108 ┆ 0.00315    ┆ 0.006725 │
# │ 630]      ┆ 1196]     ┆ null]     ┆          ┆     ┆          ┆          ┆            ┆          │
# │ [515,     ┆ [1146,    ┆ [null,    ┆ 5        ┆ ... ┆ 0.004401 ┆ 0.005285 ┆ 0.003423   ┆ 0.004894 │
# ...

# %%
num = 5
for key in parts.keys():
    print(key)
    display(parts[key].filter(
                             pl.col('PB1').arr.concat(['PB2', 'PB3', 'PB4']).arr.eval(pl.element() > 511).arr.sum() == 4
    ).sort('AUC', descending=True).head(num))
# Out:
# 02L
# shape: (5, 17)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬──────────┬──────────┬────────────┬──────────┐
# │ PB1       ┆ PB2       ┆ PB3       ┆ PB4      ┆ ... ┆ BalAcc_s ┆ TPR_std  ┆ precision_ ┆ TNR_std  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆     ┆ td       ┆ ---      ┆ std        ┆ ---      │
# │ list[i64] ┆ list[i64] ┆ list[i64] ┆ list[i64 ┆     ┆ ---      ┆ f64      ┆ ---        ┆ f64      │
# │           ┆           ┆           ┆ ]        ┆     ┆ f64      ┆          ┆ f64        ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪══════════╪══════════╪════════════╪══════════╡
# │ [39, 52]  ┆ [84, 102] ┆ [555,     ┆ [516,    ┆ ... ┆ 0.000796 ┆ 0.004213 ┆ 0.003555   ┆ 0.005569 │
# │           ┆           ┆ 566]      ┆ 520]     ┆     ┆          ┆          ┆            ┆          │
# │ [3, 6]    ┆ [84, 102] ┆ [555,     ┆ [516,    ┆ ... ┆ 0.005624 ┆ 0.011663 ┆ 0.003507   ┆ 0.005198 │
# ...

# %%
parts['02L'].sort('AUC', descending=True)
# Out:
# shape: (640, 17)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬──────────┬──────────┬────────────┬──────────┐
# │ PB1       ┆ PB2       ┆ PB3       ┆ PB4      ┆ ... ┆ BalAcc_s ┆ TPR_std  ┆ precision_ ┆ TNR_std  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆     ┆ td       ┆ ---      ┆ std        ┆ ---      │
# │ list[i64] ┆ list[i64] ┆ list[i64] ┆ list[i64 ┆     ┆ ---      ┆ f64      ┆ ---        ┆ f64      │
# │           ┆           ┆           ┆ ]        ┆     ┆ f64      ┆          ┆ f64        ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪══════════╪══════════╪════════════╪══════════╡
# │ [515,     ┆ [2, 9]    ┆ [17, 22]  ┆ [32, 37] ┆ ... ┆ 0.005771 ┆ 0.008417 ┆ 0.007072   ┆ 0.009405 │
# │ 516]      ┆           ┆           ┆          ┆     ┆          ┆          ┆            ┆          │
# │ [30, 33]  ┆ [515,     ┆ [13, 17]  ┆ [36, 37] ┆ ... ┆ 0.004107 ┆ 0.010598 ┆ 0.009038   ┆ 0.012854 │
# ...

# %%
import scipy.fft as fft

def index_to_frequency(index_list, sampling_rate, window_length):
    """
    Returns the corresponding frequency bin of the FFT output frequency bins
    calculated using Scipy library.
    """
    nyquist_freq = sampling_rate / 2.0
    frequency_bins = fft.fftfreq(window_length, 1.0/sampling_rate)
    index_to_freq = []
    
    for index in index_list:
        freq = abs(frequency_bins[index])
        if freq > nyquist_freq:
            freq = sampling_rate - freq
        index_to_freq.append(freq)
    return index_to_freq

# %%
index_to_frequency([2, 4], 500, 1024)
# Out:
# [0.9765625, 1.953125]

# %%
sys.path.append('../databasing')
from database_calls import get_device_as_pl_df, get_gains_from_settings, get_settings_for_pb_calcs
sys.path.append('../data_processing')
from data_transforms import chunk_df_by_timesegment
from rcssim_helpers import add_simulated_ffts
import duckdb

# %%
con = duckdb.connect('/media/shortterm_ssd/Clay/databases/duckdb/rcs-db.duckdb')

# %%
df = get_device_as_pl_df('02L', con, lazy=False)

# %%
con = duckdb.connect(database=DATABASE_PATH, read_only=True)
    
df = get_device_as_pl_df(device, con, lazy=True)

sessions = df.select('SessionIdentity').unique().collect().to_dict(
        as_series=False)['SessionIdentity']
settings = get_settings_for_pb_calcs(device, con, sessions, 'SessionIdentity')
gains = get_gains_from_settings(
    sessions, 'SessionIdentity', device, con)


# TODO: TD_BG need not be gains[0]. Could be gains[1]... I should use the TDSettings table to get correct gain for subcortical channel
gains_tmp = []
for channel in ['TD_BG', 'TD_key2', 'TD_key3']:
    if channel == 'TD_BG':
        gains_tmp.append(gains[0])
    if channel == 'TD_key2':
        gains_tmp.append(gains[1])
    if channel == 'TD_key3':
        gains_tmp.append(gains[2])
gains = gains_tmp

df_chunked = chunk_df_by_timesegment(df)
df_chunked = add_simulated_ffts(df_chunked, settings, gains)
