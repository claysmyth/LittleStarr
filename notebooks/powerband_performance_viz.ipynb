# %%
# %load_ext autoreload
# %autoreload 2

# %%
import altair as alt
import polars as pl
import pandas as pd
import sys
sys.path.append('../visualization_functions')
import altair_utils as alt_utils

# %%
import plotly.io as pio
alt.data_transformers.disable_max_rows()
dataspell = False
use_data_server = True # Use data server if you want to use the Vega Editor window
use_browser_for_plotly=False
remote = True

# The below commands allow for Altair to plot large data sets.

if dataspell:
    if use_data_server:
        alt.data_transformers.enable('data_server') # <- Exports to temporary localHost URL
        print('Data Server Enabled')
    else:
        vf.enable()
        print('VegaFusion Enabled')
    if use_browser_for_plotly:
        pio.renderers.default = 'browser'
    print("DataSpell Setup")
else:
    if not remote:
        # DO NOT RUN BELOW IN REMOTE VSCODE.
        if use_data_server:
            alt.data_transformers.enable('data_server') # <- Exports to temporary localHost URL
            print('Data Server Enabled')
        else:
            vf.enable_widget(data_dir='/media/shortterm_ssd/Clay/altairdata/')
            print('VegaFusion Widget Enabled')

    if use_browser_for_plotly:
        pio.renderers.default = 'browser'
        print("Plotly Browser Enabled")

    from plotly_resampler import register_plotly_resampler, unregister_plotly_resampler
    register_plotly_resampler(mode='auto')
    print("Plotly Resampler Enabled")
    print("VS Code")
'''
Available templates:
        ['ggplot2', 'seaborn', 'simple_white', 'plotly',
         'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
         'ygridoff', 'gridon', 'none']
'''
pio.templates.default = "plotly_white"
# Out:
# Plotly Resampler Enabled
# VS Code

# %%
parts = {}
charts = {}
parts_2 = {}

# %%
parts['02L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02L/hyperparameter_search_results_only_cortical.parquet')
parts['02R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02R/hyperparameter_search_results_only_cortical.parquet')
parts['03L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03L/hyperparameter_search_results_only_cortical.parquet')
parts['03R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03R/hyperparameter_search_results_only_cortical.parquet')
parts['07L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07L/hyperparameter_search_results_only_cortical.parquet')
parts['07R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07R/hyperparameter_search_results_only_cortical.parquet')
parts['09L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09L/hyperparameter_search_results_only_cortical.parquet')
parts['09R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09R/hyperparameter_search_results_only_cortical.parquet')
parts['16L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16L/hyperparameter_search_results_only_cortical.parquet')
parts['16R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16R/hyperparameter_search_results_only_cortical.parquet')

# %%
parts_2['02L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02L/hyperparameter_search_results.parquet')
parts_2['02R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS02R/hyperparameter_search_results.parquet')
parts_2['03L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03L/hyperparameter_search_results.parquet')
parts_2['03R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS03R/hyperparameter_search_results.parquet')
parts_2['07L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07L/hyperparameter_search_results.parquet')
parts_2['07R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS07R/hyperparameter_search_results.parquet')
parts_2['09L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09L/hyperparameter_search_results.parquet')
parts_2['09R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS09R/hyperparameter_search_results.parquet')
parts_2['16L'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16L/hyperparameter_search_results.parquet')
parts_2['16R'] = pl.read_parquet('/media/shortterm_ssd/Clay/databases/Sleep_10day_with_autonomic/RCS16R/hyperparameter_search_results.parquet')

# %%
# graphs = ['Acc', 'AUC', 'BalAcc', 'TPR', 'precision', 'TNR']
graphs = ['AUC']
for key, part in parts.items():
    chart=alt.vconcat()
    for i, col in enumerate(graphs):
        df = part.sort(col, descending=True).with_row_count().head(200).to_pandas()
        chart_tmp, df = alt_utils.create_overlaid_line_plot(df, ['row_nr'], ['Acc', 'AUC', 'TPR', 'TNR'], width=500, height=300, color_scheme='category10', interactive=True)
        chart &= chart_tmp
    charts[key] = chart

# %%
for key, chart in charts.items():
    chart = chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    ).properties(
        title={
            "text": key,
            "fontSize": 25,
            "fontWeight": "bold",
            "anchor": "middle"
        }
    )
    display(chart)
# Out:
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %%
# graphs = ['Acc', 'AUC', 'BalAcc', 'TPR', 'precision', 'TNR']
graphs = ['AUC']
for key, part in parts_2.items():
    chart=alt.vconcat()
    for i, col in enumerate(graphs):
        df = part.sort(col, descending=True).with_row_count().head(200).to_pandas()
        chart_tmp, df = alt_utils.create_overlaid_line_plot(df, ['row_nr'], ['Acc', 'AUC', 'TPR', 'TNR'], width=500, height=300, color_scheme='category10', interactive=True)
        chart &= chart_tmp
    charts[key] = chart
for key, chart in charts.items():
    chart = chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    ).properties(
        title={
            "text": key,
            "fontSize": 25,
            "fontWeight": "bold",
            "anchor": "middle"
        }
    )
    display(chart)
# Out:
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %%
for key, chart in charts.items():
    chart = chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    ).properties(
        title={
            "text": key,
            "fontSize": 25,
            "fontWeight": "bold",
            "anchor": "middle"
        }
    )
    display(chart)
# Out:
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %%
sup_chart = alt.vconcat()

graphs = ['AUC']
for key, part in parts.items():
    for i, col in enumerate(graphs):
        df = part.sort(col, descending=True).with_row_count().head(200).to_pandas()
        chart_tmp, df = alt_utils.create_overlaid_line_plot(df, ['row_nr'], ['Acc', 'AUC', 'BalAcc', 'TPR', 'precision', 'TNR'], width=500, height=300, color_scheme='category10', interactive=True)
        chart_tmp.properties(title={'text': key, 'fontSize': 25, 'fontWeight': 'bold', 'anchor': 'middle'})
        sup_chart &= chart_tmp

sup_chart.configure_legend(
        labelFontSize=30,
        titleFontSize=20,
        symbolSize=500
    )
# Out:
# alt.VConcatChart(...)

# %%
num = 20
for key in parts.keys():
    print(key)
    display(parts[key].sort('AUC', descending=True).head(num))
    print('Subcortical')
    display(parts_2[key].sort('AUC', descending=True).head(num))
# Out:
# 02L
# shape: (20, 17)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬──────────┬──────────┬────────────┬──────────┐
# │ PB1       ┆ PB2       ┆ PB3       ┆ PB4      ┆ ... ┆ BalAcc_s ┆ TPR_std  ┆ precision_ ┆ TNR_std  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆     ┆ td       ┆ ---      ┆ std        ┆ ---      │
# │ list[i64] ┆ list[i64] ┆ list[i64] ┆ list[i64 ┆     ┆ ---      ┆ f64      ┆ ---        ┆ f64      │
# │           ┆           ┆           ┆ ]        ┆     ┆ f64      ┆          ┆ f64        ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪══════════╪══════════╪════════════╪══════════╡
# │ [3, 6]    ┆ [84, 118] ┆ [39, 52]  ┆ [555,    ┆ ... ┆ 0.006283 ┆ 0.005251 ┆ 0.006213   ┆ 0.008754 │
# │           ┆           ┆           ┆ 566]     ┆     ┆          ┆          ┆            ┆          │
# │ [39, 52]  ┆ [105,     ┆ [3, 6]    ┆ [84,     ┆ ... ┆ 0.007656 ┆ 0.003349 ┆ 0.011279   ┆ 0.01665  │
# ...

# %%
parts['02L'].select(pl.all().exclude(list(set([col for col in parts['02L'].columns if 'PB' in col]) - set(['PB1', 'PB2', 'PB4']))))
# Out:
# shape: (640, 16)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬──────────┬──────────┬────────────┬──────────┐
# │ PB1       ┆ PB2       ┆ PB4       ┆ UpdateRa ┆ ... ┆ BalAcc_s ┆ TPR_std  ┆ precision_ ┆ TNR_std  │
# │ ---       ┆ ---       ┆ ---       ┆ te       ┆     ┆ td       ┆ ---      ┆ std        ┆ ---      │
# │ list[i64] ┆ list[i64] ┆ list[i64] ┆ ---      ┆     ┆ ---      ┆ f64      ┆ ---        ┆ f64      │
# │           ┆           ┆           ┆ i64      ┆     ┆ f64      ┆          ┆ f64        ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪══════════╪══════════╪════════════╪══════════╡
# │ [515,     ┆ [1146,    ┆ [null,    ┆ 2        ┆ ... ┆ 0.003494 ┆ 0.006108 ┆ 0.00315    ┆ 0.006725 │
# │ 630]      ┆ 1196]     ┆ null]     ┆          ┆     ┆          ┆          ┆            ┆          │
# │ [515,     ┆ [1146,    ┆ [null,    ┆ 5        ┆ ... ┆ 0.004401 ┆ 0.005285 ┆ 0.003423   ┆ 0.004894 │
# ...

# %%
parts['02L'].with_column(
    tmp=pl.col(pb_cols[0]).arr.concat(pl.col(pb_cols[1:]))
    )
# Out:
# /tmp/ipykernel_1139235/2581836268.py:1: DeprecationWarning: `DataFrame.with_column` has been renamed; this redirect is temporary, please use `.with_columns` instead
#   parts['02L'].with_column(tmp=pl.col(pb_cols[0]).arr.concat(pl.col(pb_cols[1:])))
# shape: (640, 18)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬──────────┬────────────┬──────────┬──────────┐
# │ PB1       ┆ PB2       ┆ PB3       ┆ PB4      ┆ ... ┆ TPR_std  ┆ precision_ ┆ TNR_std  ┆ tmp      │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆     ┆ ---      ┆ std        ┆ ---      ┆ ---      │
# │ list[i64] ┆ list[i64] ┆ list[i64] ┆ list[i64 ┆     ┆ f64      ┆ ---        ┆ f64      ┆ list[i64 │
# │           ┆           ┆           ┆ ]        ┆     ┆          ┆ f64        ┆          ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪══════════╪════════════╪══════════╪══════════╡
# │ [515,     ┆ [1146,    ┆ [null,    ┆ [null,   ┆ ... ┆ 0.006108 ┆ 0.00315    ┆ 0.006725 ┆ [515,    │
# ...

# %%
import numpy as np
tmp = np.arange(10)
tmp2 = tmp[0:5]
tmp2[2:4] = 100
print(tmp)
# Out:
# [  0   1 100 100   4   5   6   7   8   9]

# %%
{f"yo{i}": i for i in range(10)}
# Out:
# {'yo0': 0,
#  'yo1': 1,
#  'yo2': 2,
#  'yo3': 3,
#  'yo4': 4,
#  'yo5': 5,
#  'yo6': 6,
#  'yo7': 7,
#  'yo8': 8,
#  'yo9': 9}

# %%
tmp = [0]
tmp[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1139235/886080865.py in <cell line: 2>()
#       1 tmp = [0]
# ----> 2 tmp[1]
#
# IndexError: list index out of range

# %%
parts['02L_cort'].sort('AUC', descending=True).head(20)
# Out:
# shape: (20, 17)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬──────────┬──────────┬────────────┬──────────┐
# │ PB1       ┆ PB2       ┆ PB3       ┆ PB4      ┆ ... ┆ BalAcc_s ┆ TPR_std  ┆ precision_ ┆ TNR_std  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆     ┆ td       ┆ ---      ┆ std        ┆ ---      │
# │ list[i64] ┆ list[i64] ┆ list[i64] ┆ list[i64 ┆     ┆ ---      ┆ f64      ┆ ---        ┆ f64      │
# │           ┆           ┆           ┆ ]        ┆     ┆ f64      ┆          ┆ f64        ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪══════════╪══════════╪════════════╪══════════╡
# │ [3, 6]    ┆ [84, 118] ┆ [39, 52]  ┆ [555,    ┆ ... ┆ 0.006283 ┆ 0.005251 ┆ 0.006213   ┆ 0.008754 │
# │           ┆           ┆           ┆ 566]     ┆     ┆          ┆          ┆            ┆          │
# │ [39, 52]  ┆ [105,     ┆ [3, 6]    ┆ [84,     ┆ ... ┆ 0.007656 ┆ 0.003349 ┆ 0.011279   ┆ 0.01665  │
# ...
